# %% [markdown]
# <a href="https://colab.research.google.com/github/rena-ds/manipulation-custchurn/blob/main/Data_Manipulation_on_Telco_Customer_Churn_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libraries
import pandas as pd
import os
import zipfile
import numpy as np

# %%
#Set directory for Kaggle file
os.environ['KAGGLE_CONFIG_DIR'] = os.path.expanduser('~/.kaggle')

#Command to download dataset
# !kaggle datasets download -d "blastchar/telco-customer-churn"

#Extract ZIP file with zipfile
with zipfile.ZipFile("telco-customer-churn.zip", 'r') as zip_ref:
    zip_ref.extractall()

#Read dataset file(CSV)
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/blastchar/telco-customer-churn
# License(s): copyright-authors
# telco-customer-churn.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.size
# Out:
# 147903

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include = 'object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
pd.to_numeric(df['TotalCharges'], errors='coerce')
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %% [markdown]
# # Find customers who are at high risk of churn with the criteria that customers must have a monthly contract and their monthly bill is above the 90th percentile.

# %%
df['MonthlyCharges'].value_counts()
# Out:
# MonthlyCharges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: count, Length: 1585, dtype: int64

# %%
df['Contract']
# Out:
# 0       Month-to-month
# 1             One year
# 2       Month-to-month
# 3             One year
# 4       Month-to-month
#              ...
# 7038          One year
# 7039          One year
# 7040    Month-to-month
# 7041    Month-to-month
# 7042          Two year
# Name: Contract, Length: 7043, dtype: object

# %%
df.mcpersentil90 = np.percentile(df['MonthlyCharges'], 90)
condition = (df['Contract'] == 'Month-to-month') & (df['MonthlyCharges'] > df.mcpersentil90)
df.pelangganrisikotinggi = df[condition]
df.pelangganrisikotinggi
# Out:
# <ipython-input-49-58dd799dd232>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.pelangganrisikotinggi = df[condition]
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 38    5380-WJKOV    Male              0      No         No      34
# 83    9919-YLNNG  Female              0      No         No      42
# ...          ...     ...            ...     ...        ...     ...
# 6914  7142-HVGBG    Male              1     Yes         No      43
# 6952  6394-MFYNG  Female              0      No         No      48
# 7006  0093-XWZFY    Male              0      No         No      40
# ...

# %% [markdown]
# The 207 customers in the high-risk category, may be dissatisfied with the service or perceive the cost as too high.

# %% [markdown]
# # Grouping data by contract type and calculating average monthly billing and churn percentage for each group.

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})

# %%
df['Churn'].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
df.contractgroup = df.groupby('Contract').agg({'MonthlyCharges':'mean', 'Churn' : 'mean'})
df.contractgroup['Churn (%)'] = df.contractgroup['Churn'] * 100
df.contractgroup
# Out:
#                 MonthlyCharges     Churn  Churn (%)
# Contract
# Month-to-month       66.398490  0.427097  42.709677
# One year             65.048608  0.112695  11.269518
# Two year             60.770413  0.028319   2.831858

# %% [markdown]
# Customers with month-to-month contracts have the highest churn percentage (42.71%) compared to customers with one or two year contracts.

# %% [markdown]
# # Pivot table to analyze the relationship between contract type and payment method on average monthly billing.

# %%
pd.pivot_table(
    data = df,
    index = 'Contract',
    columns = 'PaymentMethod',
    values = 'MonthlyCharges',
    aggfunc = 'mean'
)
# Out:
# PaymentMethod   Bank transfer (automatic)  Credit card (automatic)  \
# Contract
# Month-to-month                  69.085399                67.678821
# One year                        67.484143                67.972362
# Two year                        65.013918                64.422117
#
# PaymentMethod   Electronic check  Mailed check
# Contract
# Month-to-month         74.989486     46.050056
# One year               79.095245     44.306380
# Two year               84.335714     38.587304

# %% [markdown]
# Annual contracts have lower average monthly bills than monthly contracts. Electronic checks have the highest average bills, while mailed checks have the lowest for all contract types.

# %% [markdown]
# # Crosstab to evaluate the relationship between churn and payment method, and calculate the churn percentage for each payment method.

# %%
df.churnmethod = pd.crosstab(df['PaymentMethod'],df['Churn'])
df.churnmethod['Churn (%)'] = df.churnmethod[1]/(df.churnmethod[0]+df.churnmethod[1])*100
df.churnmethod
# Out:
# <ipython-input-58-63c6c37c0f26>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.churnmethod = pd.crosstab(df['PaymentMethod'],df['Churn'])
# Churn                         0     1  Churn (%)
# PaymentMethod
# Bank transfer (automatic)  1286   258  16.709845
# Credit card (automatic)    1290   232  15.243101
# Electronic check           1294  1071  45.285412
# Mailed check               1304   308  19.106700

# %% [markdown]
# Payment method has a significant relationship with churn. Customers with Electronic check payment method showed the highest churn percentage compared to other payment methods.

# %% [markdown]
# # Aggregation to evaluate total churn with senior citizen yes and dependents more than 0.

# %%
df['Dependents'] = df['Dependents'].map({'Yes': 1, 'No': 0})
condition = (df['SeniorCitizen'] == 1) & (df['Dependents'] > 0)
df.condi = df[condition]
df.condi
# Out:
# <ipython-input-59-b80ae5b0d6ac>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.condi = df[condition]
#       customerID  gender  SeniorCitizen Partner  Dependents  tenure  \
# 54    4667-QONEA  Female              1     Yes           1      60
# 57    5067-XJQFU    Male              1     Yes           1      66
# 72    1891-QRQSA    Male              1     Yes           1      64
# 140   3146-MSEGF  Female              1     Yes           1      72
# 308   3167-SNQPL    Male              1     Yes           1      38
# ...          ...     ...            ...     ...         ...     ...
# 6235  5180-UCIIQ    Male              1     Yes           1      22
# 6346  9661-MHUMO    Male              1     Yes           1       1
# 6446  2205-LPVGL    Male              1     Yes           1      58
# ...

# %% [markdown]
# There are 91 out of 7043 customers who are Senior Citizens with dependents > 0 and experienced churn. This shows that this group has a small contribution to the total churn as a whole.
